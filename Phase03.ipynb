# %% [markdown]
# # Phase 03 — Graph Construction

# %%
# Phase 03 — Graph Construction
import pandas as pd
import numpy as np
import torch
import json
from torch_geometric.data import HeteroData

# Load what Phase 01 saved
df = pd.read_csv('content/sample_data/df_preprocessed.csv')

# Load the top 40 V-features Phase 02 picked
with open('content/sample_data/useful_v_features.json', 'r') as f:
    useful_v_features = json.load(f)

print(f"Transactions : {len(df):,}")
print(f"Useful V-features selected: {len(useful_v_features)}")
